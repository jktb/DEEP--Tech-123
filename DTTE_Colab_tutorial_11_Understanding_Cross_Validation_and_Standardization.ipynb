# %% [markdown]
# <a href="https://colab.research.google.com/github/jktb/DEEP--Tech-123/blob/main/DTTE_Colab_tutorial_11_Understanding_Cross_Validation_and_Standardization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### CLASSIFICATION-1
# ### Understanding Cross-Validation and Standardization
#
# ---

# %% [markdown]
# # **Section 1: Tweaking the parameters**

# %% [markdown]
# Let's stat the lab by writing knn code on a cancer detection dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.neighbors import KNeighborsClassifier
from sklearn import datasets

# %%
cancer = datasets.load_breast_cancer(as_frame=True)

# %%
cancer.target_names
# Out:
# array(['malignant', 'benign'], dtype='<U9')

# %%
cancer.frame
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                   0.07871  ...          17.33           184.60      2019.0
# 1                   0.05667  ...          23.41           158.80      1956.0
# 2                   0.05999  ...          25.53           152.50      1709.0
# 3                   0.09744  ...          26.50            98.87       567.7
# 4                   0.05883  ...          16.67           152.20      1575.0
# ..                      ...  ...            ...              ...         ...
# 564                 0.05623  ...          26.40           166.10      2027.0
# 565                 0.05533  ...          38.25           155.00      1731.0
# 566                 0.05648  ...          34.12           126.70      1124.0
# 567                 0.07016  ...          39.42           184.60      1821.0
# 568                 0.05884  ...          30.37            59.16       268.6
#
#      worst smoothness  worst compactness  worst concavity  \
# 0             0.16220            0.66560           0.7119
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      worst concave points  worst symmetry  worst fractal dimension  target
# 0                  0.2654          0.4601                  0.11890       0
# 1                  0.1860          0.2750                  0.08902       0
# 2                  0.2430          0.3613                  0.08758       0
# 3                  0.2575          0.6638                  0.17300       0
# 4                  0.1625          0.2364                  0.07678       0
# ..                    ...             ...                      ...     ...
# 564                0.2216          0.2060                  0.07115       0
# 565                0.1628          0.2572                  0.06637       0
# 566                0.1418          0.2218                  0.07820       0
# 567                0.2650          0.4087                  0.12400       0
# 568                0.0000          0.2871                  0.07039       1
#
# [569 rows x 31 columns]

# %%
X = cancer.data
y = cancer.target

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 17)

# %% [markdown]
# ## Section 1.1: Changing Value of K
# Let's try to run the knn with different values of knn and compare the results

# %%
neighbors = []
scores_list = []

for k in range(1, 25):
    neighbors.append(k)
    knn = KNeighborsClassifier(n_neighbors = k)
    knn.fit(X_train,y_train)
    scores = knn.score(X_test,y_test)
    scores_list.append(scores)

# %%
Accuracy = [x*100 for x in scores_list]
# plot Accuracy versus k
plt.figure(figsize = (10, 6))
plt.plot(neighbors, Accuracy)
plt.xlim([0, 25])
plt.xlabel('Number of neighbors')
plt.ylabel('Accuracy in %')
plt.show()

# %%
# determining the best k
max_acc = max(Accuracy)
optimal_ks = [neighbors[i] for i, j in enumerate(Accuracy) if j == max_acc]
print(max_acc)
print(optimal_ks)
# Out:
# 93.61702127659575
# [10, 12, 13, 14, 22, 24]

# %% [markdown]
# In this case, we see that the ideal number of neighbours can take any one of the values in the list [10,12,13,14,22,24].
# However, this only tells us the effectiveness of the KNN classifier only if we have the same train-test split considered above. It still does not tell us how well the algorithm would perform if the test set were different. The results would have been different if we had split the data differently.

# %% [markdown]
# ### AUC-ROC Curve

# %% [markdown]
# The AUC - ROC curve is a performance measurement for classification problems at various threshold settings. ROC is a probability curve and AUC represents the degree or measure of separability.
# It tells how much the model is capable of distinguishing between classes.
# The diagonal in the curve divides the ROC space. Points above the diagonal represent good classification results (better than random); points below the line represent bad results (worse than random).
# Higher the AUC, the better the model is at predicting 0 classes as 0 and 1 classes as 1.
#
# The ROC curve is plotted with the TPR (True Positive Rate) on the y-axis, and the FPR (False Positive Rate) on the x-axis.

# %%
## AUC-ROC
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
import matplotlib.pyplot as plt

def plot_roc(y_test,predicted):
  y_scores = predicted
  fpr, tpr, threshold = roc_curve(y_test, y_scores)
  roc_auc = auc(fpr, tpr)
  plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
  plt.legend(loc = 'lower right')
  plt.plot([0, 1], [0, 1],'r--')
  plt.xlim([0, 1])
  plt.ylim([0, 1])
  plt.ylabel('True Positive Rate')
  plt.xlabel('False Positive Rate')
  plt.title('Receiver Operating Characteristic')
  plt.show()

# %%
knn = KNeighborsClassifier(n_neighbors = 10)
knn.fit(X_train,y_train)
predictions = knn.predict(X_test)
plot_roc(y_test,predictions)

# %% [markdown]
# ## Section 1.2: KNN using a different train-test split

# %%
## Changing the random_state value here so that data is split differently
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 1089)

# %%
neighbors = []
scores_list = []

for k in range(1, 25):
    neighbors.append(k)
    knn = KNeighborsClassifier(n_neighbors = k)
    knn.fit(X_train,y_train)
    scores = knn.score(X_test,y_test)
    scores_list.append(scores)

# %%
Accuracy = [x*100 for x in scores_list]
# plot Accuracy versus k
plt.figure(figsize = (10, 6))
plt.plot(neighbors, Accuracy)
plt.xlim([0, 25])
plt.xlabel('Number of neighbors')
plt.ylabel('Accuracy in %')
plt.show()

# %%
# determining the best k
max_acc = max(Accuracy)
optimal_ks = [neighbors[i] for i, j in enumerate(Accuracy) if j == max_acc]
print(max_acc)
print(optimal_ks)
# Out:
# 94.14893617021278
# [5, 7, 8]

# %% [markdown]
# As you can see, the model gives different results when we split the data differently. Here, it suggests that the ideal k value is 5, 7 or 8.

# %% [markdown]
# # **Section 2: Cross Validation**

# %% [markdown]
# As you saw in the above two cases with different train-test splits, there is a risk of overfitting on the test set because the parameters can be tweaked until the estimator performs optimally. This way, knowledge about the test set can “leak” into the model and evaluation metrics no longer report on generalization performance.
#
# Cross Validation is an important technique in Machine Learning to analyze the performance of a model on **unseen** data.
#
# There are different kinds of cross-validation methods: exhaustive and non-exhaustive.
# Exhaustive cross-validation methods are cross-validation methods which learn and test on all possible ways to divide the original sample into a training and a validation set.
# Non-exhaustive cross validation methods do not compute all ways of splitting the original sample.
#
# One of the most commonly cross-validation methods is **K-Fold Cross validation**. The procedure for K-Fold Cross Validation is as follows:
# 1. Split the dataset into k groups (typically without shuffling)
# 2. For each unique group:
#   a. Take the group as a hold out or test data set
#   b. Take the remaining groups as a training data set
#   c. Fit a model on the training set and evaluate it on the test set
#   d. Retain the evaluation score and discard the model
# 3. Summarize the performance of the model using the mean of model evaluation scores over all the folds.

# %% [markdown]
# Image source: https://scikit-learn.org/stable/modules/cross_validation.html
# ![Screenshot from 2021-12-13 09-37-46.png](data:image/png;base64,...)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 17)

# %%
from sklearn.model_selection import KFold
from statistics import mean
kf = KFold(n_splits=10)
cv_scores = []
neighbors = []
for k in range(1,25):
  knn = KNeighborsClassifier(n_neighbors = k)
  neighbors.append(k)
  acclist = []
  for train_index, test_index in kf.split(X_train, y_train):
    x_train_fold, x_test_fold = X_train.iloc[train_index], X_train.iloc[test_index]
    y_train_fold, y_test_fold = y_train.iloc[train_index], y_train.iloc[test_index]
    knn.fit(x_train_fold, y_train_fold)
    acclist.append(knn.score(x_test_fold, y_test_fold))
  cv_scores.append(mean(acclist))

# %%
Accuracy = [x*100 for x in cv_scores]

# plot misclassification error versus k
plt.figure(figsize = (10, 6))
plt.plot(neighbors, Accuracy)
plt.xlabel('Number of neighbors')
plt.ylabel('Mean Cross-validation accuracy in %')
plt.show()

# %%
# determining the best k
max_acc = max(Accuracy)
optimal_ks = [neighbors[i] for i, j in enumerate(Accuracy) if j == max_acc]
print(optimal_ks)
# Out:
# [10, 12]

# %% [markdown]
# Note that the accuracy in the above case is not the accuracy on the test set. We plot the mean of the accuracies obtained during cross-validation, when we considered different splits of the training set.
#
# From the plot above, we can see that when the value of k is 10 or 12, our KNN model generalizes well to unseen data. Performing such cross validation gives us an idea about the parameters to choose when using a machine-learning algorithm.

# %%
## TASK-1:
## In the above case, we saw K-Fold cross validation, where we split the dataset into K consecutive folds without taking anything else into account.
## Stratified KFold is another strategy that is commonly used, which preserves the percentage of samples for each class in the folds.
## Implement Stratified KFold (refer Sklearn docs) and display the results you obtain

# %%
from sklearn.model_selection import StratifiedKFold
from statistics import mean
skf = StratifiedKFold(n_splits=10,shuffle=True, random_state=1)
skf_cv_scores = []
neighbors = []
for k in range(1,25):
  knn = KNeighborsClassifier(n_neighbors = k)
  neighbors.append(k)
  skf_acclist = []
  for train_index, test_index in skf.split(X_train, y_train):
    x_train_fold, x_test_fold = X_train.iloc[train_index], X_train.iloc[test_index]
    y_train_fold, y_test_fold = y_train.iloc[train_index], y_train.iloc[test_index]
    knn.fit(x_train_fold, y_train_fold)
    skf_acclist.append(knn.score(x_test_fold, y_test_fold))
  skf_cv_scores.append(mean(skf_acclist))

# %%
Accuracy = [x*100 for x in skf_cv_scores]
# plot Accuracy versus k
plt.figure(figsize = (10, 6))
plt.plot(neighbors, Accuracy)
plt.xlim([0, 25])
plt.xlabel('Number of neighbors')
plt.ylabel('Accuracy in %')
plt.show()

# %%
# determining the best k
max_acc = max(Accuracy)
optimal_ks = [neighbors[i] for i, j in enumerate(Accuracy) if j == max_acc]
print(max_acc)
print(optimal_ks)
# Out:
# 94.22402159244264
# [5, 6]

# %% [markdown]
# # **Section 3: Standardization**

# %% [markdown]
# Scaling the data that we have available is a recommended pre-processing step when working with many machine learning algorithms. The scale and distribution of the data drawn from the domain may be different for each variable. Differences in the scales across input variables may increase the difficulty of the problem being modeled, and the model may suffer from poor performance during learning and sensitivity to input values resulting in higher generalization error.
#
# Standardization (also called z-score normalization) is one such scaling technique that transforms your data such that the resulting distribution has a mean of 0 and a standard deviation of 1.
#
# $$ \text{New (scaled) value} = {X - \mu \over \sigma}$$

# %%
X = cancer.data
y = cancer.target

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size = 0.33, random_state = 17)

# %%
neighbors = []
scores_list = []

for k in range(1, 25):
    neighbors.append(k)
    knn = KNeighborsClassifier(n_neighbors = k)
    knn.fit(X_train,y_train)
    scores = knn.score(X_test,y_test)
    scores_list.append(scores)

# %%
Accuracy = [x*100 for x in scores_list]
# plot Accuracy versus k
plt.figure(figsize = (10, 6))
plt.plot(neighbors, Accuracy)
plt.xlim([0, 25])
plt.xlabel('Number of neighbors')
plt.ylabel('Accuracy in %')
plt.show()

# %%
# determining the best k
max_acc = max(Accuracy)
optimal_ks = [neighbors[i] for i, j in enumerate(Accuracy) if j == max_acc]
print(max_acc)
print(optimal_ks)
# Out:
# 96.80851063829788
# [2]

# %%
## TASK-2:
## Plot a confusion matrix for the classification above on the scaled data (using the optimal value of k)
## Also print out the Precision, Recall and F1-score values

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import KFold
from statistics import mean


X = cancer.data
y = cancer.target
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size = 0.33, random_state = 17)
neighbors = []
scores_list = []

for k in range(1, 25):
    neighbors.append(k)
    knn = KNeighborsClassifier(n_neighbors = k)
    knn.fit(X_train,y_train)
    scores = knn.score(X_test,y_test)
    scores_list.append(scores)
Accuracy = [x*100 for x in scores_list]
# plot Accuracy versus k
plt.figure(figsize = (10, 6))
plt.plot(neighbors, Accuracy)
plt.xlim([0, 25])
plt.xlabel('Number of neighbors')
plt.ylabel('Accuracy in %')
plt.show()
max_acc = max(Accuracy)
optimal_ks = [neighbors[i] for i, j in enumerate(Accuracy) if j == max_acc]
print(max_acc)
print(optimal_ks)

# Confusion matrix and metrics using the optimal k
optimal_k = optimal_ks[0]
optimal_knn = KNeighborsClassifier(n_neighbors=optimal_k)
optimal_knn.fit(X_train_scaled, y_train)
y_pred = optimal_knn.predict(X_test_scaled)

conf_matrix = confusion_matrix(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print("Confusion Matrix:")
print(conf_matrix)
print("Precision:", precision)
print("Recall:", recall)
print("F1-Score:", f1)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
# Out:
# 96.80851063829788
# [2]
# Confusion Matrix:
# [[ 63   4]
#  [  2 119]]
# Precision: 0.967479674796748
# Recall: 0.9834710743801653
# F1-Score: 0.9754098360655739

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score

# Load the breast cancer dataset
cancer = load_breast_cancer()
X = cancer.data
y = cancer.target

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=17)

# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Find the optimal k using original train-test split
neighbors = list(range(1, 25))
scores_list = []

for k in neighbors:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train_scaled, y_train)
    scores = knn.score(X_test_scaled, y_test)
    scores_list.append(scores)

max_acc = max(scores_list)
optimal_ks = [neighbors[i] for i, j in enumerate(scores_list) if j == max_acc]

print("Max Accuracy (Original Split):", max_acc)
print("Optimal k (Original Split):", optimal_ks)

# Plot Accuracy versus k
plt.figure(figsize=(10, 6))
plt.plot(neighbors, scores_list)
plt.xlim([0, 25])
plt.xlabel('Number of neighbors')
plt.ylabel('Accuracy')
plt.title('Accuracy vs. Number of Neighbors')
plt.show()

# Perform K-Fold Cross Validation
cv_scores_list = []

for k in neighbors:
    knn = KNeighborsClassifier(n_neighbors=k)
    cv_scores = cross_val_score(knn, X_train_scaled, y_train, cv=5)
    cv_scores_list.append(np.mean(cv_scores))

cv_max_acc = max(cv_scores_list)
cv_optimal_ks = [neighbors[i] for i, j in enumerate(cv_scores_list) if j == cv_max_acc]

print("Max Accuracy (Cross Validation):", cv_max_acc)
print("Optimal k (Cross Validation):", cv_optimal_ks)

# Plot Cross Validation Accuracy versus k
plt.figure(figsize=(10, 6))
plt.plot(neighbors, cv_scores_list)
plt.xlim([0, 25])
plt.xlabel('Number of neighbors')
plt.ylabel('Cross Validation Accuracy')
plt.title('Cross Validation Accuracy vs. Number of Neighbors')
plt.show()

max_acc = max(Accuracy)
optimal_ks = [neighbors[i] for i, j in enumerate(Accuracy) if j == max_acc]
print("Optimal k is", optimal_ks, " and maximum accuracy is ", max_acc)
# Out:
# Max Accuracy (Original Split): 0.9680851063829787
# Optimal k (Original Split): [2, 10]
# Max Accuracy (Cross Validation): 0.9633287764866711
# Optimal k (Cross Validation): [3]
# Optimal k is [2]  and maximum accuracy is  96.80851063829788

# %% [markdown]
# ### Questions to Think About and Answer
# 1. Instead of using cross-validation, we could also split our dataset into three sets- train, validation, and test set. The training proceeds on the training set, after which evaluation is done on the validation set, and when the experiment seems to be successful, final evaluation can be done on the test set.
# What do you think are the pros/cons of this method ?
#
# 2. Is K-Fold cross validation an exhaustive or non-exhaustive cross validation method ? Justify your answer.
#
# 3. Why is it important to use different train-test splits with varying random_state values in "Section 1.2: KNN using a different train-test split"? What insight does this approach provide in terms of model evaluation?
#
# 4. In "Section 3: Standardization," the code employs StandardScaler for data preprocessing. Describe the purpose of standardization in machine learning and briefly explain how StandardScaler transforms the data. Could you outline a scenario where using Min-Max scaling instead of standardization might be more appropriate?

# %% [markdown]
# **Answer-1**
#
# Pros:
#
#     1. Controlled Hyperparameter Tuning: By having a separate validation set, you can tune your model's hyperparameters (like the number of neighbors in KNN) on the validation set. This helps prevent overfitting to the test set and provides a more accurate estimation of your model's performance on new, unseen data.
#
#     2. Model Selection: You can experiment with different algorithms and architectures and select the best-performing one using the validation set. This prevents data leakage from affecting your model's evaluation on the test set.
#
#     3. Realistic Evaluation: The test set serves as a more realistic evaluation of your model's generalization performance on new, unseen data. It gives you an idea of how well your model will perform in real-world scenarios.
#
#   Cons:
#
#    1. Data Splitting: Splitting the data into three sets means you have less data available for training. This can be an issue if your dataset is small. K-Fold Cross Validation uses the entire dataset for training in each fold.
#
#     2. Data Imbalance: If your dataset is imbalanced, you might need to ensure that the class distribution is similar across the training, validation, and test sets. Otherwise, your model's performance might be biased.
#
#     3. Randomness: The random split into training, validation, and test sets can lead to variations in results based on the random seed used. K-Fold Cross Validation can help reduce this variability.
#
#  **Answer-2**
#
#  In each fold of K-Fold Cross Validation, a subset of the data is selected for validation/testing, and the remaining data is used for training. The subsets change in each fold, and the same data point can appear in both training and validation/testing subsets across different folds. This is in contrast to exhaustive methods like Leave-One-Out Cross Validation (LOOCV), where each data point is used for validation exactly once.
#
#  non-exhaustive" refers to the fact that not all possible combinations of training and validation sets are used. In other words, the algorithm doesn't consider all possible ways to partition the data. Instead, it samples different subsets of the data to train and validate the model.
#
#  **Answer-3**
#
#  The performance of a machine learning model can be influenced by the specific subset of data used for training and testing. If a single train-test split is used, the results might be biased towards the characteristics of that particular data split. By using different random_state values to generate different train-test splits, you reduce the risk of drawing conclusions based on a single data partition, which could be unrepresentative of the overall dataset.
#
#  To perform hyperparameter tuning (e.g., choosing the optimal value of K in KNN), using different train-test splits can help you make more informed decisions. The performance of a specific hyperparameter value might vary depending on the data partition. Evaluating different hyperparameters across multiple splits provides a more comprehensive view of their effectiveness.
#
#  **Answer-4**
#
#  The purpose of standardization is to bring all features to a similar scale, which can improve the performance of certain algorithms and models that are sensitive to the scale of the input features.StandardScaler, a common preprocessing tool, transforms the data by subtracting the mean of each feature from each data point and then dividing by the standard deviation of that feature.
#  1. Standardization makes features comparable, removing the issues that arise when different features have different scales
#
#  2. standardization can improve the effectiveness of regularization techniques, helping to prevent overfitting.

# %% [markdown]
# ### Useful Resources for further reading
# 1. Cross validation (scikit-learn): https://scikit-learn.org/stable/modules/cross_validation.html
# 2. Wikipedia: https://en.wikipedia.org/wiki/Cross-validation_(statistics)
# 3. Standardization: https://machinelearningmastery.com/standardscaler-and-minmaxscaler-transforms-in-python/
# 4. AUC-ROC : https://en.wikipedia.org/wiki/Receiver_operating_characteristic
